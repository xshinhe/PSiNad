# %%
import pypsnd

print(dir(pypsnd))
print(dir(pypsnd.lib))

print(pypsnd.lib.chem.elem.C)
print(pypsnd.lib.chem.elem.ElementList[6])
print(pypsnd.lib.chem.getElemLabel(6))
print(pypsnd.lib.chem.getElemMass(6))
# Out:
# ['PSNDException', '__author__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_psnd', 'absolute_import', 'example', 'ext', 'lib', 'libpypsnd_v1', 'os', 'sys', 'version']
# ['Context', 'DataSet', 'Kernel', 'Model', 'Param', 'Platform', 'Shape', 'Solver', 'Status', 'System', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'chem', 'defaultModelFactory', 'defaultSolverFactory', 'phys', 'usePlatform']
# Elem <C>
# Elem <C>
# C
# 12.01078
